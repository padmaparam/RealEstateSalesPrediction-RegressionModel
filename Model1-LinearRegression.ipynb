# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
X_train = pd.read_csv('data/X_train_scaled.csv')
y_train = pd.read_csv('data/y_train.csv')
X_test = pd.read_csv('data/X_test_scaled.csv')
y_test = pd.read_csv('data/y_test.csv')

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_tr_pred = lr.predict(X_train)
resid = y_tr_pred - y_train
lr.score(X_train, y_train)
# Out:
# 0.5045756930479637

# %%
# %sns.regplot(y_train,y_tr_pred)

# %%
y_te_pred = lr.predict(X_test)
plt.scatter(y_test, y_te_pred)

# %%
lr = LinearRegression(normalize=True)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
r2_score = r2_score(y_test, y_pred)
print("R2 score: %f" % (r2_score))

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %f" % (rmse))
# Out:
# R2 score: -669899040641634661855920128.000000
# RMSE: 10189285197753888768.000000

# %% [markdown]
# As the prediction is way off the actual value, we will try other models
